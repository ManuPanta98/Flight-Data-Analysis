# %% [markdown]
# # Class FlightAnalysis Showcase
#
# In this notebook we are presenting the narrative of `FlightAnalyisis`, an innovative class our team designed to enhance airline operational efficiency and environmental sustainability.
#
# ### Scenario Description
# Carlo, a sustainability consultant collaborating with EcoFlight Solution is committing himself to create a model for airlines that optimizes flight routes to minimize carbon footprint and operational costs. The project, named "EcoSky Strategy", is set to revolutionize the way airlines approach flight planning.

# %% [markdown]
# ### Step 1: Data Gathering
# Carlo starts the project by sourcing a comprehensive set of data to analyze the existing flight patterns and environmental impact. The data includes various parameters about flight schedules, aircraft types, fuel usage, and emission statistics. The aim is to get a baseline understanding of the current state and identify potential areas for improvement.
#
# **Method Used**: The __init__ method within `FlightAnalyisis` is crafted to preprocess and structure the vast data into a coherent, analyzable format for Jamie's further exploration.

# %%
import sys
sys.path.append('analysis')

from FlightAnalysis import FlightAnalysis
fa = FlightAnalysis()

# %% [markdown]
# Carlo examines the initialized data to confirm its integrity, ensuring a solid foundation for the analysis steps ahead.

# %%
print(f'The FeatherFlight object was created on the {fa.date_created}')
print(f'1. It has the airline dataset {fa.airline_data.shape}.')
print(f'2. It also has the airports dataset {fa.airport_data.shape}.')
print(f'3. It also has the aircraft dataset {fa.aircraft_data.shape}.')
print(f'4. It also has the routes dataset {fa.flight_routes.shape}.')
# Out:
# The FeatherFlight object was created on the 2024-03-17
# 1. It has the airline dataset (6162, 9).
# 2. It also has the airports dataset (7698, 15).
# 3. It also has the aircraft dataset (246, 4).
# 4. It also has the routes dataset (67663, 7).

# %%
for df in [fa.airline_data, fa.airport_data, fa.flight_routes, fa.aircraft_data]:
    display(df.head(5))
# Out:
#    index  Airline ID                                          Name Alias IATA  \
# 0      0          -1                                       Unknown    \N    -
# 1      1           1                                Private flight    \N    -
# 2      2           2                                   135 Airways    \N  NaN
# 3      3           3                                 1Time Airline    \N   1T
# 4      4           4  2 Sqn No 1 Elementary Flying Training School    \N  NaN
#
#   ICAO Callsign         Country Active
# 0  NaN       \N              \N      Y
# 1  NaN      NaN             NaN      Y
# 2  GNL  GENERAL   United States      N
# 3  RNX  NEXTIME    South Africa      Y
# 4  WYT      NaN  United Kingdom      N
#    index Airport ID                                         Name  \
# 0      0          1                               Goroka Airport
# 1      1          2                               Madang Airport
# 2      2          3                 Mount Hagen Kagamuga Airport
# 3      3          4                               Nadzab Airport
# 4      4          5  Port Moresby Jacksons International Airport
#
#            City           Country IATA  ICAO  Latitude   Longitude  Altitude  \
# 0        Goroka  Papua New Guinea  GKA  AYGA -6.081690  145.391998      5282
# 1        Madang  Papua New Guinea  MAG  AYMD -5.207080  145.789001        20
# 2   Mount Hagen  Papua New Guinea  HGU  AYMH -5.826790  144.296005      5388
# 3        Nadzab  Papua New Guinea  LAE  AYNZ -6.569803  146.725977       239
# 4  Port Moresby  Papua New Guinea  POM  AYPY -9.443380  147.220001       146
#
#   Timezone DST Tz database time zone     Type       Source
# 0       10   U  Pacific/Port_Moresby  airport  OurAirports
# 1       10   U  Pacific/Port_Moresby  airport  OurAirports
# 2       10   U  Pacific/Port_Moresby  airport  OurAirports
# 3       10   U  Pacific/Port_Moresby  airport  OurAirports
# 4       10   U  Pacific/Port_Moresby  airport  OurAirports
#    index Airline ID Source airport ID Destination airport ID Codeshare  Stops  \
# 0      0        410              2965                   2990       NaN      0
# 1      1        410              2966                   2990       NaN      0
# 2      2        410              2966                   2962       NaN      0
# 3      3        410              2968                   2990       NaN      0
# 4      4        410              2968                   4078       NaN      0
#
#   Equipment
# 0       CR2
# 1       CR2
# 2       CR2
# 3       CR2
# 4       CR2
#    index                                          Name IATA code ICAO code
# 0      0                       Aerospatiale (Nord) 262       ND2      N262
# 1      1  Aerospatiale (Sud Aviation) Se.210 Caravelle       CRV      S210
# 2      2                  Aerospatiale SN.601 Corvette       NDC      S601
# 3      3                Aerospatiale/Alenia ATR 42-300       AT4      AT43
# 4      4                Aerospatiale/Alenia ATR 42-500       AT5      AT45

# %% [markdown]
# ### Step 2
# With everything set, Carlo next step is to analyze the distances of existing routes to identify potential inefficiencies and opportunities for optimization.
#
# **Methods Used**:
# - `update_route_distances`: to calculate distances between airports using latitude and longitude coordinates and update the flight_routes DataFrame with these calculated distance.
# - `distance_analysis`: To visualize the distribution of flight distances, helping to understand long-haul flights that could be made more efficient.

# %%
fa.update_route_distances()
fa.distance_analysis()
display(fa.flight_routes.head())

# %% [markdown]
# ### Step 3
#
# After having analysed distances distribution. Carlo shifts focus to internal operations within a specific country. He found out thayt the flight emission of Italy is particularly high, thus he wants to find out what could he do to reduce their impact. He starts by looking at where aiprots are located in Italy and how
#
# **Methods Used**:
# - `country_airports`: To plot and examine the locations of all airports within the country, understanding geographical spread.
# - `plot_flights`: Focusing on major airports, Alex plots all departing flights to assess the density and distribution of internal vs. international flights.

# %%
fa.plot_airports_by_country('Italy')
# Out:
# /Users/manuelpantaleo/Desktop/Advance programming/adpro2024-main/Group_16/analysis/FlightAnalysis.py:145: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %% [markdown]
# He moves forward with the analysis and start searching for all the flights that departs from Italy. He does so by using a new method called `plot_flights_on_map` this method  plots flight routes on a world map, differentiating between short-haul and long-haul flights.

# %%
#all flights
fa.plot_flights_on_map("Italy", internal = False)

# %% [markdown]
# By looking at internal flights in Italy he founds out that the emission of those flight are equal to 36.93 tonnes and the potential CO2 emissions replacing short-haul with rails could be 5.63 tonnes. Thus, he starts thinking about a new solution to reduce emissions in Italy.

# %% [markdown]
# Another idea that Carlo come up with is to find the busiest airports in Italy, Carlo found out that one of the airports with more flights is the Malpensa airport. Therefore, he wants to understand what are the flights that originate from there.

# %%
# All flights
fa.plot_flights_from_airport('MXP', internal=False)

# %%
# Domestic flights
fa.plot_flights_from_airport('MXP', internal=True)

# %% [markdown]
# ### Step 4
# With a focus narrowed to Italy, Carlo investigates the types of aircraft dominating the skies, aiming to suggest more fuel-efficient alternatives. The “EcoSky Strategy” hinges on not just how and where planes fly, but also what planes are flying.
#
# **Method Used**:
# - `plot_top_airplane_models`: This method visualizes the most frequently used airplane models in Italy's airspace.
#
# By understanding which models are most common, Carlo can assess their fuel efficiency and environmental impact.

# %%
fa.plot_top_airplane_models(countries='Italy', N=10)

# %% [markdown]
# Carlo generates a bar chart showing the top 10 airplane models by the number of routes they cover. The chart reveals a dominant presence of older models like the BH2 and 320, which, while reliable, are not the pinnacle of fuel efficiency. Now Carlo has some more information at hand of what are the causes of increasing emissions.

# %% [markdown]
# #### Step 5
# In this step Carlo wants to have a list with all aircraft models so that it can b e used for his researches. Thus, he uses the method `aircrafts` which prints a list of unique aircraft models contained in the dataset.

# %%
fa.aircrafts()
# Out:
# List of Aircraft Models:
# Aerospatiale (Nord) 262
# Aerospatiale (Sud Aviation) Se.210 Caravelle
# Aerospatiale SN.601 Corvette
# Aerospatiale/Alenia ATR 42-300
# Aerospatiale/Alenia ATR 42-500
# Aerospatiale/Alenia ATR 42-600
# Aerospatiale/Alenia ATR 72
# Airbus A300
# Airbus A300-600
# Airbus A300-600ST Super Transporter / Beluga
# Airbus A310
# Airbus A318
# Airbus A319
# Airbus A319neo
# Airbus A320
# Airbus A320neo
# Airbus A321
# Airbus A321neo
# Airbus A330
# Airbus A330-200
# Airbus A330-300
# Airbus A330-700 Beluga XL
# Airbus A330-800neo
# Airbus A330-900neo
# Airbus A340
# Airbus A340-200
# Airbus A340-300
# Airbus A340-500
# Airbus A340-600
# Airbus A350
# Airbus A350-1000
# Airbus A350-900
# Airbus A380
# Airbus A380-800
# Antonov AN-12
# Antonov AN-124 Ruslan
# Antonov AN-140
# Antonov An-148
# Antonov An-158
# Antonov An-225 Mriya
# Antonov AN-24
# Antonov AN-26
# Antonov AN-28
# Antonov AN-30
# Antonov AN-32
# Antonov AN-72
# Avro RJ100
# Avro RJ70
# Avro RJ85
# BAe 146
# BAe 146-100
# BAe 146-200
# BAe 146-300
# Beechcraft 1900
# Beechcraft Baron
# Beechcraft Baron / 55 Baron
# Bell 212
# Boeing 707
# Boeing 717
# Boeing 720B
# Boeing 727
# Boeing 727-100
# Boeing 727-200
# Boeing 737
# Boeing 737 MAX 10
# Boeing 737 MAX 7
# Boeing 737 MAX 8
# Boeing 737 MAX 9
# Boeing 737-200
# Boeing 737-300
# Boeing 737-400
# Boeing 737-500
# Boeing 737-600
# Boeing 737-700
# Boeing 737-800
# Boeing 737-900
# Boeing 747
# Boeing 747 LCF Dreamlifter
# Boeing 747-100
# Boeing 747-200
# Boeing 747-300
# Boeing 747-400
# Boeing 747-400D
# Boeing 747-8
# Boeing 747SP
# Boeing 747SR
# Boeing 757
# Boeing 757-200
# Boeing 757-300
# Boeing 767
# Boeing 767-200
# Boeing 767-300
# Boeing 767-400
# Boeing 777
# Boeing 777-200
# Boeing 777-200LR
# Boeing 777-300
# Boeing 777-300ER
# Boeing 777-8
# Boeing 777-9
# Boeing 787
# Boeing 787-10
# Boeing 787-8
# Boeing 787-9
# Bombardier 415
# Bombardier BD-100 Challenger 300
# Bombardier CS100
# Bombardier CS300
# Bombardier Global Express
# British Aerospace (BAC) One Eleven
# British Aerospace 125 series / Hawker/Raytheon 700/800/800XP/850/900
# British Aerospace 125-1000 series / Hawker/Raytheon 1000
# British Aerospace ATP
# British Aerospace Jetstream 31
# British Aerospace Jetstream 32
# British Aerospace Jetstream 41
# Canadair Challenger
# Canadair CL-44
# Canadair Regional Jet 100
# Canadair Regional Jet 1000
# Canadair Regional Jet 200
# Canadair Regional Jet 700
# Canadair Regional Jet 900
# Cessna 152
# Cessna 172
# Cessna 182 Skylane
# Cessna 208 Caravan
# Cessna 210 Centurion
# Cessna Citation CJ3
# Cessna Citation CJ4
# Cessna Citation Excel
# Cessna Citation I
# Cessna Citation II
# Cessna Citation Mustang
# Cessna Citation Sovereign
# Cessna Citation X
# COMAC C-919
# Concorde
# Dassault Falcon 2000
# Dassault Falcon 50
# Dassault Falcon 7X
# Dassault Falcon 900
# De Havilland Canada DHC-2 Beaver
# De Havilland Canada DHC-2 Turbo-Beaver
# De Havilland Canada DHC-3 Otter
# De Havilland Canada DHC-4 Caribou
# De Havilland Canada DHC-6 Twin Otter
# De Havilland Canada DHC-7 Dash 7
# De Havilland Canada DHC-8-100 Dash 8 / 8Q
# De Havilland Canada DHC-8-200 Dash 8 / 8Q
# De Havilland Canada DHC-8-300 Dash 8
# De Havilland Canada DHC-8-400 Dash 8Q
# De Havilland DH.104 Dove
# De Havilland DH.114 Heron
# Douglas DC-10
# Douglas DC-3
# Douglas DC-6
# Douglas DC-8-50
# Douglas DC-8-62
# Douglas DC-8-72
# Douglas DC-9-10
# Douglas DC-9-20
# Douglas DC-9-30
# Douglas DC-9-40
# Douglas DC-9-50
# Embraer 170
# Embraer 175
# Embraer 175 (long wing)
# Embraer 175 (short wing)
# Embraer 190
# Embraer 195
# Embraer E190-E2
# Embraer E195-E2
# Embraer EMB 110 Bandeirante
# Embraer EMB 120 Brasilia
# Embraer Legacy 450
# Embraer Legacy 600
# Embraer Phenom 100
# Embraer Phenom 300
# Embraer RJ135
# Embraer RJ140
# Embraer RJ145
# Fairchild Dornier 328JET
# Fairchild Dornier Do.228
# Fairchild Dornier Do.328
# Fokker 100
# Fokker 50
# Fokker 70
# Fokker F27 Friendship
# Fokker F28 Fellowship
# Gulfstream Aerospace G-159 Gulfstream I
# Gulfstream G280
# Gulfstream G650
# Gulfstream IV
# Gulfstream V
# Gulfstream/Rockwell (Aero) Commander
# Gulfstream/Rockwell (Aero) Turbo Commander
# Harbin Yunshuji Y12
# Hawker Siddeley HS 748
# Ilyushin IL114
# Ilyushin IL18
# Ilyushin IL62
# Ilyushin IL76
# Ilyushin IL86
# Ilyushin IL96
# Learjet 35
# Learjet 60
# Lockheed L-1011 Tristar
# Lockheed L-1049 Super Constellation
# Lockheed L-182 / 282 / 382 (L-100) Hercules
# Lockheed L-188 Electra
# McDonnell Douglas MD-11
# McDonnell Douglas MD-81
# McDonnell Douglas MD-82
# McDonnell Douglas MD-83
# McDonnell Douglas MD-87
# McDonnell Douglas MD-88
# McDonnell Douglas MD-90
# NAMC YS-11
# Partenavia P.68
# Pilatus Britten-Norman BN-2A Mk III Trislander
# Pilatus Britten-Norman BN-2A/B Islander
# Pilatus PC-12
# Pilatus PC-6 Turbo Porter
# Piper PA-28 (above 200 hp)
# Piper PA-28 (up to 180 hp)
# Piper PA-31 Navajo
# Piper PA-44 Seminole
# Piper PA-46
# Saab 2000
# Saab SF340A/B
# Shorts SC-5 Belfast
# Shorts SC-7 Skyvan
# Shorts SD.330
# Shorts SD.360
# Sikorsky S-58T
# Sikorsky S-61
# Sikorsky S-76
# Sikorsky S-92
# Sukhoi Superjet 100-95
# Tupolev Tu-134
# Tupolev Tu-144
# Tupolev Tu-154
# Tupolev Tu-204
# Yakovlev Yak-40
# Yakovlev Yak-42

# %% [markdown]
# Now, Carlo wants to get more information regarding some of the aircraft most used in Italy so uses a method called `aircraft_info` developed by in the class FlightAnalyisi to find out some generic information about aircrafts

# %%
info = fa.aircraft_info("Aerospatiale (Sud Aviation) Se.210 Caravelle")
print(info)
# Out:
# | Specification            | Value                           |
# |--------------------------|---------------------------------|
# | Manufacturer             | Aerospatiale (Sud Aviation)     |
# | Model                    | Se.210 Caravelle                |
# | Role                     | Narrow-body jet airliner        |
# | First flight             | 27 May 1955                     |
# | Introduction             | 1959                            |
# | Produced                 | 1955-1972                       |
# | Number built             | 282                             |
# | Crew                     | 2 cockpit crew                  |
# | Capacity                 | 80-140 passengers               |
# | Length                   | 32.01 m (105 ft 0 in)           |
# | Wingspan                 | 34.3 m (112 ft 6 in)            |
# | Height                   | 8.72 m (28 ft 7 in)             |
# | Maximum takeoff weight   | 47,000 kg (103,617 lb)          |
# | Engines                  | 2x Rolls-Royce Avon turbojets   |
# | Maximum speed            | 900 km/h (559 mph)               |
# | Range                    | 3,700 km (2,300 mi)             |
# | Service ceiling          | 12,000 m (39,000 ft)            |
# None

# %% [markdown]
# He is not happy with that so as he wants this information to be more organized, thus he uses another method called `aircraft_info_markdown`which generates a markdown content with information about a specified aircraft model by invoking the OpenAI Chat model as the previous method.

# %%
info_ = fa.aircraft_info_markdown("Aerospatiale (Sud Aviation) Se.210 Caravelle")
print(info_)
# Out:
# | Specification           | Value                        |
# |-------------------------|------------------------------|
# | Manufacturer            | Aerospatiale (Sud Aviation)  |
# | Model                   | Se.210 Caravelle             |
# | Role                    | Narrow-body jet airliner     |
# | First flight            | 27 May 1955                  |
# | Introduction            | 1959                         |
# | Produced                | 1955-1972                    |
# | Number built            | 282                          |
# | Crew                    | 3                            |
# | Capacity                | 80-140 passengers            |
# | Length                  | 32.01 m (105 ft)             |
# | Wingspan                | 34.3 m (112 ft 6 in)         |
# | Height                  | 8.72 m (28 ft 7 in)          |
# | Maximum takeoff weight  | 47,000 kg (103,617 lb)       |
# | Engines                 | 2 x Rolls-Royce Avon         |
# | Maximum speed           | 870 km/h (540 mph)           |
# | Range                   | 3,700 km (2,300 mi)          |
# | Service ceiling         | 12,000 m (39,370 ft)         |
# None

# %% [markdown]
# Finally carlo wants to understand what are the detail about Malpensa airport. Thus, he uses a method called `analysis.airport_info`.

# %%
info_2 = fa.airport_info("Catania")
print(info_2)
# Out:
# | Specification        | Value          |
# |----------------------|----------------|
# | Airport Name         | Catania Airport |
# | Location             | Catania, Sicily, Italy |
# | IATA Code            | CTA            |
# | ICAO Code            | LICC           |
# | Elevation            | 39 meters      |
# | Number of Terminals  | 1              |
# | Number of Runways    | 1              |
# | Runway Length        | 2,442 meters   |
# | Passenger Traffic    | 9.9 million (2019) |
# | Airlines             | Over 40        |
# | Destinations         | 100+           |
# None

# %% [markdown]
# With all this information The "EcoSky Strategy" is beginning to take flight, and with each data point, Carlo is one step closer to a cleaner, greener future for aviation in Italy.
